# %%
# import sys
# sys.path.append('/Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/')

import numpy as np
import matplotlib.pyplot as plt
import torch
import warnings
from gpytorch.kernels import MaternKernel, ScaleKernel, RQKernel
import matplotlib as mpl
from BO_loop import BO_loop_GP, GP_Wrapper
from data import BayesOptDataset, FuncAckley
from sklearn.preprocessing import MinMaxScaler
import copy
from matplotlib.lines import Line2D
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.gridspec as gridspec

warnings.filterwarnings('ignore')

# %%
class FuncGriewank:
    def __init__(self, dim=1, maximize=False):
        self.dim = dim
        self.dims = dim  # For compatibility
        self.maximize = maximize
        
        # Bounds per dimension
        self.lb = np.full((dim,), -80.0)
        self.ub = np.full((dim,), 80.0)
        
        # MinMaxScaler expects 2D input
        self.inputs_scaler = MinMaxScaler()
        self.inputs_scaler.fit(np.vstack([self.lb, self.ub]))
        
        # Global minimum at origin
        self._opt_inputs = np.zeros((1, dim))

    def _scale_inputs(self, X):
        X = np.atleast_2d(X)
        assert X.shape[1] == self.dim, f"Expected input with {self.dim} dimensions, got {X.shape[1]}"
        return self.inputs_scaler.inverse_transform(X)

    def query(self, X):
        X = self._scale_inputs(X)
        term1 = np.sum(X**2, axis=1) / 4000
        term2 = np.prod(np.cos(X / np.sqrt(np.arange(1, self.dim + 1))), axis=1)
        result = (term1 - term2 + 1).reshape(-1, 1)
        return -result if self.maximize else result

    def get_opts(self):
        Xopts = self.inputs_scaler.transform(self._opt_inputs)
        yopts = self.query(Xopts)
        return Xopts, yopts

# %%
# Set random seeds
SEED = 0
np.random.seed(SEED)
torch.manual_seed(SEED)

KERNEL_FLAGS = {
    "mat52": {"kernel": "mat52", "set_ls": False, "if_ard": False},
    "mat12": {"kernel": "mat12", "set_ls": False, "if_ard": False},
    "rq":    {"kernel": "rq",    "set_ls": False, "if_ard": False},
    "gcauchy": {"kernel": "gcauchy", "set_ls": False, "if_ard": False}
}

# Define consistent colors
colors_dict = {
    "gp_mean": "#1f77b4",       # blue
    "true_func": "#000000",     # black
    "samples": "#2ca02c",       # green
    "global_min": "#d62728",    # red
    "fill": "#1f77b4",          # same as gp_mean, but transparent
}

# %%
def BO_UCB_plot_grid(kernel_types, kernel_names, dataset, total_iter=15, beta=1.5):
    # Configure plotting style
    mpl.rcParams.update({
        'font.family': 'sans-serif',
        'font.sans-serif': ['Arial', 'DejaVu Sans', 'Liberation Sans'],
        'font.size': 11,
        'axes.labelsize': 11,
        'axes.titlesize': 11,
        'xtick.labelsize': 10,
        'ytick.labelsize': 10,
        'legend.fontsize': 10,
        'figure.titlesize': 11,
        'figure.dpi': 200
    })

    num_rows = len(kernel_types)
    milestones = [0, total_iter // 3, 2 * total_iter // 3, total_iter]
    num_cols = len(milestones)

    fig = plt.figure(figsize=(8, 2.5 * num_rows + 1), constrained_layout=True, dpi=200)
    gs = gridspec.GridSpec(num_rows + 1, num_cols,
                           height_ratios=[1] + [1] * num_rows,
                           figure=fig)
                           
    # Get true function values for plotting
    lb = dataset.func.lb
    ub = dataset.func.ub
    X_plot = np.linspace(lb[0], ub[0], 100)
    Y_plot = np.linspace(lb[1], ub[1], 100)
    X_grid, Y_grid = np.meshgrid(X_plot, Y_plot)
    XY_grid = np.column_stack((X_grid.ravel(), Y_grid.ravel()))
    Z_true = dataset.func.query(XY_grid).reshape(X_grid.shape)
    
    # True contour plot (using original scale)
    ax_true = fig.add_subplot(gs[0, 0])
    cntr = ax_true.contourf(X_grid, Y_grid, Z_true, levels=30, cmap='viridis')
    
    x_init_denorm = dataset.func.inputs_scaler.inverse_transform(dataset.X)
    ax_true.scatter(x_init_denorm[:, 0], x_init_denorm[:, 1], c='red', edgecolors='k', s=40, linewidth=0.5)
    
    x_true_min_denorm, _ = dataset.func.get_opts()
    ax_true.scatter(x_true_min_denorm[:, 0], x_true_min_denorm[:, 1], c='green', marker='*', s=150)
    
    ax_true.set_title("True Contour Plot")
    ax_true.set_xlabel("x1")
    ax_true.set_ylabel("x2")

    divider = make_axes_locatable(ax_true)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    cbar = fig.colorbar(cntr, cax=cax)
    cbar.set_label("Objective Value")
    
    # Legend in the top row
    legend_ax = fig.add_subplot(gs[0, 1:])
    legend_ax.axis('off')
    handles = [
        plt.Line2D([], [], marker='o', linestyle='', color='red', markeredgecolor='k', markersize=8, label='Samples'),
        plt.Line2D([], [], marker='*', linestyle='', color='green', markersize=12, label='True Minimum')
    ]
    legend_ax.legend(handles=handles, loc='center', frameon=False, ncol=2)

    for i, kernel_type in enumerate(kernel_types):
        current_dataset = dataset.clone()
        flags = KERNEL_FLAGS[kernel_type]
        base_kern = flags["kernel"]
        set_ls = flags["set_ls"]
        if_ard = flags["if_ard"]

        X_init, Y_init = current_dataset.get_data(normalize=True)
        gp_model = GP_Wrapper(
            X_init, Y_init,
            kernel=base_kern,
            if_ard=if_ard,
            if_softplus=True,
            set_ls=set_ls,
            device="cpu",
        )
        gp_model.init_optimizer(lr=0.1, optim="ADAM")
        gp_model.step(epochs=1000)

        for j, n in enumerate(milestones):
            if n > 0:
                BO_loop_GP(
                    func_name="Ackley",
                    dataset=current_dataset,
                    seed=SEED,
                    num_step=n - milestones[j-1],
                    beta=beta,
                    if_ard=if_ard,
                    if_softplus=True,
                    acqf_type="UCB",
                    set_ls=set_ls,
                    kernel_type=base_kern,
                    full_kernel_name=kernel_type,
                    device="cpu"
                )
                X, Y = current_dataset.get_data(normalize=True)
                gp_model.update_train_data(X, Y)
                gp_model.step(epochs=50)

            ax = fig.add_subplot(gs[i + 1, j])

            mu, _ = plot_gp_state_2d(gp_model, dataset, X_grid, Y_grid, ax)
            cntr_gp = ax.contourf(X_grid, Y_grid, mu, levels=30, cmap='viridis')
            
            X_denorm = dataset.func.inputs_scaler.inverse_transform(current_dataset.X)
            ax.scatter(X_denorm[:, 0], X_denorm[:, 1], c='red', edgecolors='k', s=40, linewidth=0.5)

            x_true_min_denorm, _ = dataset.func.get_opts()
            ax.scatter(x_true_min_denorm[:, 0], x_true_min_denorm[:, 1], c='green', marker='*', s=150)

            ax.set_title(f"{kernel_names[i]}, Iter {n}")
            
            if i == num_rows - 1:
                ax.set_xlabel("x1")
            else:
                ax.set_xticklabels([])
            
            if j == 0:
                ax.set_ylabel("x2")
            else:
                ax.set_yticklabels([])

    plt.show()
    plt.close()

def plot_gp_state_2d(gp, dataset, X_grid, Y_grid, ax):
    gp.gp_model.eval()
    gp.likelihood.eval()
    
    XY_grid = np.column_stack((X_grid.ravel(), Y_grid.ravel()))
    XY_grid_norm = dataset.func.inputs_scaler.transform(XY_grid)
    
    with torch.no_grad():
        posterior = gp.likelihood(gp.gp_model(torch.tensor(XY_grid_norm)))
    
    mu_norm = posterior.mean.numpy()
    mu = mu_norm * dataset.scaler.scale_[0] + dataset.scaler.mean_[0]
    mu = mu.reshape(X_grid.shape)
    
    return mu, None

if __name__ == "__main__":
    func_2d = FuncGriewank(dim=2, maximize=False)
    #func_2d = FuncAckley(dim=2)
    dataset_2d = BayesOptDataset(func_2d, n_init=20, method='lhs', seed=SEED)
    
    kernel_types = ["mat52", "mat12", "rq","gcauchy"]
    kernel_names = ["Matern 5/2", "Matern 1/2", "Rational Quadratic","Generalized Cauchy"]

    print("Generating 2D plots for Ackley function...")
    BO_UCB_plot_grid(
        kernel_types=kernel_types,
        kernel_names=kernel_names,
        dataset=dataset_2d,
        total_iter=100,
        beta=1.5
    )
# Out:
# Generating 2D plots for Ackley function...
# Cloning
# [GP_Wrapper.step] 1000 epochs: 16.616856 → 1.197909 (Δ=15.418948, rel=92.79%)
# [GP_Wrapper.step] 2000 epochs: 16.616856 → 1.197906 (Δ=15.418950, rel=92.79%)
# Seed: 0 --- Kernel: mat52 --- itr: 21: best before=4.073756088146656, best after=4.310365442805317, curr query: [4.31036544], time=2.550s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.079421 → 1.061030 (Δ=0.018391, rel=1.70%)
# Seed: 0 --- Kernel: mat52 --- itr: 22: best before=4.310365442805317, best after=4.310365442805317, curr query: [4.31036544], time=0.076s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.959184 → 0.947648 (Δ=0.011536, rel=1.20%)
# Seed: 0 --- Kernel: mat52 --- itr: 23: best before=4.310365442805317, best after=4.310365442805317, curr query: [3.33035891], time=0.100s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.976364 → 0.966369 (Δ=0.009995, rel=1.02%)
# Seed: 0 --- Kernel: mat52 --- itr: 24: best before=4.310365442805317, best after=4.310365442805317, curr query: [4.11046752], time=0.088s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.904060 → 0.895822 (Δ=0.008237, rel=0.91%)
# Seed: 0 --- Kernel: mat52 --- itr: 25: best before=4.310365442805317, best after=4.903825581614255, curr query: [4.90382558], time=0.090s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.394984 → 0.976419 (Δ=0.418565, rel=30.01%)
# Seed: 0 --- Kernel: mat52 --- itr: 26: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.31014122], time=0.110s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.042042 → 0.918307 (Δ=0.123735, rel=11.87%)
# Seed: 0 --- Kernel: mat52 --- itr: 27: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.63573771], time=0.091s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.809107 → 0.807322 (Δ=0.001785, rel=0.22%)
# Seed: 0 --- Kernel: mat52 --- itr: 28: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.47230302], time=0.090s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.714868 → 0.713827 (Δ=0.001040, rel=0.15%)
# Seed: 0 --- Kernel: mat52 --- itr: 29: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.44757133], time=0.088s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.633868 → 0.633229 (Δ=0.000639, rel=0.10%)
# Seed: 0 --- Kernel: mat52 --- itr: 30: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.43415238], time=0.149s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.561999 → 0.561585 (Δ=0.000415, rel=0.07%)
# Seed: 0 --- Kernel: mat52 --- itr: 31: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.44633314], time=0.096s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.494446 → 0.494162 (Δ=0.000284, rel=0.06%)
# Seed: 0 --- Kernel: mat52 --- itr: 32: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.45603459], time=0.084s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.431743 → 0.431533 (Δ=0.000209, rel=0.05%)
# Seed: 0 --- Kernel: mat52 --- itr: 33: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.46610036], time=0.084s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.373619 → 0.373457 (Δ=0.000162, rel=0.04%)
# Seed: 0 --- Kernel: mat52 --- itr: 34: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.47482178], time=0.081s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.319810 → 0.319680 (Δ=0.000130, rel=0.04%)
# Seed: 0 --- Kernel: mat52 --- itr: 35: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.48527369], time=0.091s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.269883 → 0.269775 (Δ=0.000108, rel=0.04%)
# Seed: 0 --- Kernel: mat52 --- itr: 36: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.49597544], time=0.082s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.223533 → 0.223440 (Δ=0.000092, rel=0.04%)
# Seed: 0 --- Kernel: mat52 --- itr: 37: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.52207901], time=0.096s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.180721 → 0.180638 (Δ=0.000083, rel=0.05%)
# Seed: 0 --- Kernel: mat52 --- itr: 38: best before=4.903825581614255, best after=4.903825581614255, curr query: [3.05379532], time=0.081s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.443393 → 1.440065 (Δ=0.003328, rel=0.23%)
# Seed: 0 --- Kernel: mat52 --- itr: 39: best before=4.903825581614255, best after=4.903825581614255, curr query: [3.51485618], time=0.084s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.896987 → 1.896898 (Δ=0.000089, rel=0.00%)
# Seed: 0 --- Kernel: mat52 --- itr: 40: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.31036544], time=0.084s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.836003 → 1.835938 (Δ=0.000065, rel=0.00%)
# Seed: 0 --- Kernel: mat52 --- itr: 41: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.31036544], time=0.084s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.776146 → 1.776092 (Δ=0.000054, rel=0.00%)
# Seed: 0 --- Kernel: mat52 --- itr: 42: best before=4.903825581614255, best after=4.903825581614255, curr query: [3.0762308], time=0.083s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 2.723887 → 2.716146 (Δ=0.007740, rel=0.28%)
# Seed: 0 --- Kernel: mat52 --- itr: 43: best before=4.903825581614255, best after=4.903825581614255, curr query: [3.97003941], time=0.096s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 2.690938 → 2.690821 (Δ=0.000118, rel=0.00%)
# Seed: 0 --- Kernel: mat52 --- itr: 44: best before=4.903825581614255, best after=4.903825581614255, curr query: [2.94712081], time=0.089s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 3.764334 → 0.703332 (Δ=3.061002, rel=81.32%)
# Seed: 0 --- Kernel: mat52 --- itr: 45: best before=4.903825581614255, best after=4.903825581614255, curr query: [2.90656894], time=0.085s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.716102 → 0.596184 (Δ=0.119918, rel=16.75%)
# Seed: 0 --- Kernel: mat52 --- itr: 46: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.81565136], time=0.104s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.584185 → 0.507106 (Δ=0.077080, rel=13.19%)
# Seed: 0 --- Kernel: mat52 --- itr: 47: best before=4.903825581614255, best after=4.903825581614255, curr query: [4.16553781], time=0.248s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.510361 → 0.510170 (Δ=0.000191, rel=0.04%)
# Seed: 0 --- Kernel: mat52 --- itr: 48: best before=4.903825581614255, best after=5.0282655363497355, curr query: [5.02826554], time=0.283s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.521579 → 0.521425 (Δ=0.000153, rel=0.03%)
# Seed: 0 --- Kernel: mat52 --- itr: 49: best before=5.0282655363497355, best after=5.0282655363497355, curr query: [4.48321251], time=0.129s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.515183 → 0.514840 (Δ=0.000344, rel=0.07%)
# Seed: 0 --- Kernel: mat52 --- itr: 50: best before=5.0282655363497355, best after=5.0282655363497355, curr query: [4.42805594], time=0.253s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.508807 → 0.508552 (Δ=0.000255, rel=0.05%)
# Seed: 0 --- Kernel: mat52 --- itr: 51: best before=5.0282655363497355, best after=5.142090009429152, curr query: [5.14209001], time=0.225s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.486436 → 0.486266 (Δ=0.000170, rel=0.03%)
# Seed: 0 --- Kernel: mat52 --- itr: 52: best before=5.142090009429152, best after=5.14258430157049, curr query: [5.1425843], time=0.185s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.451607 → 0.451434 (Δ=0.000173, rel=0.04%)
# Seed: 0 --- Kernel: mat52 --- itr: 53: best before=5.14258430157049, best after=5.14258430157049, curr query: [4.90541345], time=0.160s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 6590.099425 → 0.199694 (Δ=6589.899731, rel=100.00%)
# [GP_Wrapper.step] 2000 epochs: 180131.892828 → 1.441593 (Δ=180130.451236, rel=100.00%)
# Seed: 0 --- Kernel: mat52 --- itr: 54: best before=5.14258430157049, best after=5.14258430157049, curr query: [3.66963469], time=2.603s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.506381 → 1.398343 (Δ=0.108037, rel=7.17%)
# Seed: 0 --- Kernel: mat52 --- itr: 55: best before=5.14258430157049, best after=5.14258430157049, curr query: [3.86246712], time=0.442s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.433464 → 1.332511 (Δ=0.100954, rel=7.04%)
# Seed: 0 --- Kernel: mat52 --- itr: 56: best before=5.14258430157049, best after=5.14258430157049, curr query: [3.41943322], time=0.339s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.648378 → 1.526978 (Δ=0.121400, rel=7.36%)
# Seed: 0 --- Kernel: mat52 --- itr: 57: best before=5.14258430157049, best after=5.14258430157049, curr query: [3.95416265], time=0.208s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.560381 → 1.444988 (Δ=0.115393, rel=7.40%)
# Seed: 0 --- Kernel: mat52 --- itr: 58: best before=5.14258430157049, best after=5.14258430157049, curr query: [2.94925394], time=0.445s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.477972 → 1.371404 (Δ=0.106568, rel=7.21%)
# Seed: 0 --- Kernel: mat52 --- itr: 59: best before=5.14258430157049, best after=5.14258430157049, curr query: [3.14529794], time=0.297s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.405817 → 1.306768 (Δ=0.099049, rel=7.05%)
# Seed: 0 --- Kernel: mat52 --- itr: 60: best before=5.14258430157049, best after=5.14258430157049, curr query: [3.68229269], time=0.371s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.338717 → 1.246654 (Δ=0.092064, rel=6.88%)
# Seed: 0 --- Kernel: mat52 --- itr: 61: best before=5.14258430157049, best after=5.14258430157049, curr query: [2.85002811], time=0.272s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.272019 → 1.186702 (Δ=0.085317, rel=6.71%)
# Seed: 0 --- Kernel: mat52 --- itr: 62: best before=5.14258430157049, best after=5.14258430157049, curr query: [3.63858654], time=0.284s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.217847 → 1.138272 (Δ=0.079575, rel=6.53%)
# Seed: 0 --- Kernel: mat52 --- itr: 63: best before=5.14258430157049, best after=5.14258430157049, curr query: [3.90330994], time=0.334s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.160098 → 1.086066 (Δ=0.074032, rel=6.38%)
# Seed: 0 --- Kernel: mat52 --- itr: 64: best before=5.14258430157049, best after=5.14258430157049, curr query: [2.13308494], time=0.414s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.087151 → 1.019894 (Δ=0.067256, rel=6.19%)
# Seed: 0 --- Kernel: mat52 --- itr: 65: best before=5.14258430157049, best after=5.14258430157049, curr query: [2.51920879], time=0.400s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.037328 → 0.975159 (Δ=0.062170, rel=5.99%)
# Seed: 0 --- Kernel: mat52 --- itr: 66: best before=5.14258430157049, best after=5.14258430157049, curr query: [4.51838773], time=0.308s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.976029 → 0.919030 (Δ=0.056999, rel=5.84%)
# Seed: 0 --- Kernel: mat52 --- itr: 67: best before=5.14258430157049, best after=5.14258430157049, curr query: [5.14078731], time=0.649s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.801700 → 0.751137 (Δ=0.050563, rel=6.31%)
# Seed: 0 --- Kernel: mat52 --- itr: 68: best before=5.14258430157049, best after=5.14258430157049, curr query: [2.69504258], time=0.456s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.897381 → 0.841565 (Δ=0.055816, rel=6.22%)
# Seed: 0 --- Kernel: mat52 --- itr: 69: best before=5.14258430157049, best after=5.14258430157049, curr query: [2.86211802], time=0.295s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.878765 → 0.824136 (Δ=0.054629, rel=6.22%)
# Seed: 0 --- Kernel: mat52 --- itr: 70: best before=5.14258430157049, best after=5.14258430157049, curr query: [5.14248615], time=0.399s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.706924 → 0.658281 (Δ=0.048643, rel=6.88%)
# Seed: 0 --- Kernel: mat52 --- itr: 71: best before=5.14258430157049, best after=5.14258430157049, curr query: [3.01502365], time=0.342s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.722997 → 0.674850 (Δ=0.048147, rel=6.66%)
# Seed: 0 --- Kernel: mat52 --- itr: 72: best before=5.14258430157049, best after=5.14258430157049, curr query: [3.30177709], time=0.371s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.725309 → 0.677632 (Δ=0.047677, rel=6.57%)
# Seed: 0 --- Kernel: mat52 --- itr: 73: best before=5.14258430157049, best after=5.14258430157049, curr query: [3.70429813], time=0.425s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.717872 → 0.671200 (Δ=0.046673, rel=6.50%)
# Seed: 0 --- Kernel: mat52 --- itr: 74: best before=5.14258430157049, best after=5.14258430157049, curr query: [3.59067158], time=0.348s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.696681 → 0.651955 (Δ=0.044726, rel=6.42%)
# Seed: 0 --- Kernel: mat52 --- itr: 75: best before=5.14258430157049, best after=5.14258430157049, curr query: [3.72713619], time=0.344s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.676732 → 0.634623 (Δ=0.042108, rel=6.22%)
# Seed: 0 --- Kernel: mat52 --- itr: 76: best before=5.14258430157049, best after=5.14258430157049, curr query: [2.28941064], time=0.344s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.644090 → 0.605265 (Δ=0.038825, rel=6.03%)
# Seed: 0 --- Kernel: mat52 --- itr: 77: best before=5.14258430157049, best after=5.14258430157049, curr query: [3.83287671], time=0.574s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.648966 → 0.610026 (Δ=0.038940, rel=6.00%)
# Seed: 0 --- Kernel: mat52 --- itr: 78: best before=5.14258430157049, best after=5.14258430157049, curr query: [3.69969405], time=0.461s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.627529 → 0.590679 (Δ=0.036850, rel=5.87%)
# Seed: 0 --- Kernel: mat52 --- itr: 79: best before=5.14258430157049, best after=5.14258430157049, curr query: [4.59963235], time=0.385s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.589045 → 0.555239 (Δ=0.033806, rel=5.74%)
# Seed: 0 --- Kernel: mat52 --- itr: 80: best before=5.14258430157049, best after=5.142662092978682, curr query: [5.14266209], time=0.628s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.455119 → 0.424763 (Δ=0.030357, rel=6.67%)
# Seed: 0 --- Kernel: mat52 --- itr: 81: best before=5.142662092978682, best after=5.142662092978682, curr query: [2.37837336], time=0.396s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.466621 → 0.436792 (Δ=0.029829, rel=6.39%)
# Seed: 0 --- Kernel: mat52 --- itr: 82: best before=5.142662092978682, best after=5.142662092978682, curr query: [2.43332305], time=0.359s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.508108 → 0.476259 (Δ=0.031849, rel=6.27%)
# Seed: 0 --- Kernel: mat52 --- itr: 83: best before=5.142662092978682, best after=5.142662092978682, curr query: [2.02799399], time=0.520s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.481783 → 0.452252 (Δ=0.029531, rel=6.13%)
# Seed: 0 --- Kernel: mat52 --- itr: 84: best before=5.142662092978682, best after=5.142662092978682, curr query: [3.8189712], time=0.444s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.492166 → 0.462286 (Δ=0.029880, rel=6.07%)
# Seed: 0 --- Kernel: mat52 --- itr: 85: best before=5.142662092978682, best after=5.142680745338032, curr query: [5.14268075], time=0.411s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.369106 → 0.341986 (Δ=0.027121, rel=7.35%)
# Seed: 0 --- Kernel: mat52 --- itr: 86: best before=5.142680745338032, best after=5.142680745338032, curr query: [4.05910312], time=0.341s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.553434 → 0.559340 (Δ=-0.005905, rel=-1.07%)
# [GP_Wrapper.step] 2000 epochs: 271040.148857 → 3.015279 (Δ=271037.133578, rel=100.00%)
# Seed: 0 --- Kernel: mat52 --- itr: 87: best before=5.142680745338032, best after=5.142680745338032, curr query: [2.67079038], time=3.000s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 3.019224 → 2.862910 (Δ=0.156314, rel=5.18%)
# Seed: 0 --- Kernel: mat52 --- itr: 88: best before=5.142680745338032, best after=5.142699388363074, curr query: [5.14269939], time=0.530s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 2.714427 → 2.574040 (Δ=0.140388, rel=5.17%)
# Seed: 0 --- Kernel: mat52 --- itr: 89: best before=5.142699388363074, best after=5.142699748060498, curr query: [5.14269975], time=0.536s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 2.435700 → 2.309408 (Δ=0.126292, rel=5.19%)
# Seed: 0 --- Kernel: mat52 --- itr: 90: best before=5.142699748060498, best after=5.142699748060498, curr query: [2.60560399], time=0.277s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 2.313591 → 2.196185 (Δ=0.117406, rel=5.07%)
# Seed: 0 --- Kernel: mat52 --- itr: 91: best before=5.142699748060498, best after=5.142699748060498, curr query: [3.04313824], time=0.413s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 2.309675 → 2.190585 (Δ=0.119091, rel=5.16%)
# Seed: 0 --- Kernel: mat52 --- itr: 92: best before=5.142699748060498, best after=5.142699748060498, curr query: [5.14269972], time=0.550s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 2.064778 → 1.956070 (Δ=0.108708, rel=5.26%)
# Seed: 0 --- Kernel: mat52 --- itr: 93: best before=5.142699748060498, best after=5.142699865264954, curr query: [5.14269987], time=0.522s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.837891 → 1.739337 (Δ=0.098554, rel=5.36%)
# Seed: 0 --- Kernel: mat52 --- itr: 94: best before=5.142699865264954, best after=5.142699865264954, curr query: [3.90558546], time=0.481s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 2.035095 → 1.922627 (Δ=0.112469, rel=5.53%)
# Seed: 0 --- Kernel: mat52 --- itr: 95: best before=5.142699865264954, best after=5.142699869502456, curr query: [5.14269987], time=0.558s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.808656 → 1.704914 (Δ=0.103742, rel=5.74%)
# Seed: 0 --- Kernel: mat52 --- itr: 96: best before=5.142699869502456, best after=5.142699891897878, curr query: [5.14269989], time=0.536s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.597423 → 1.503174 (Δ=0.094248, rel=5.90%)
# Seed: 0 --- Kernel: mat52 --- itr: 97: best before=5.142699891897878, best after=5.142699891897878, curr query: [5.14269988], time=0.698s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.401484 → 1.315524 (Δ=0.085961, rel=6.13%)
# Seed: 0 --- Kernel: mat52 --- itr: 98: best before=5.142699891897878, best after=5.142699891897878, curr query: [5.14269987], time=0.570s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.219054 → 1.140353 (Δ=0.078702, rel=6.46%)
# Seed: 0 --- Kernel: mat52 --- itr: 99: best before=5.142699891897878, best after=5.142699891897878, curr query: [3.98855516], time=0.388s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.152189 → 1.077914 (Δ=0.074275, rel=6.45%)
# Seed: 0 --- Kernel: mat52 --- itr: 100: best before=5.142699891897878, best after=5.142699891897878, curr query: [5.14269988], time=0.415s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.988101 → 0.919610 (Δ=0.068491, rel=6.93%)
# Seed: 0 --- Kernel: mat52 --- itr: 101: best before=5.142699891897878, best after=5.142699891897878, curr query: [3.95087347], time=0.277s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.941776 → 0.876792 (Δ=0.064984, rel=6.90%)
# Seed: 0 --- Kernel: mat52 --- itr: 102: best before=5.142699891897878, best after=5.142699891897878, curr query: [3.87837481], time=0.468s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.086495 → 1.011269 (Δ=0.075226, rel=6.92%)
# Seed: 0 --- Kernel: mat52 --- itr: 103: best before=5.142699891897878, best after=5.142699891897878, curr query: [3.89059539], time=0.484s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.050676 → 0.975832 (Δ=0.074844, rel=7.12%)
# Seed: 0 --- Kernel: mat52 --- itr: 104: best before=5.142699891897878, best after=5.142699891897878, curr query: [3.07402773], time=0.346s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.991797 → 0.920860 (Δ=0.070937, rel=7.15%)
# Seed: 0 --- Kernel: mat52 --- itr: 105: best before=5.142699891897878, best after=5.142699891897878, curr query: [4.6220996], time=0.676s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.957158 → 0.886861 (Δ=0.070298, rel=7.34%)
# Seed: 0 --- Kernel: mat52 --- itr: 106: best before=5.142699891897878, best after=5.142699891897878, curr query: [3.79804792], time=0.421s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.909459 → 0.842677 (Δ=0.066782, rel=7.34%)
# Seed: 0 --- Kernel: mat52 --- itr: 107: best before=5.142699891897878, best after=5.142699891897878, curr query: [3.58436076], time=0.313s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.862747 → 0.799567 (Δ=0.063180, rel=7.32%)
# Seed: 0 --- Kernel: mat52 --- itr: 108: best before=5.142699891897878, best after=5.142699891897878, curr query: [5.14269971], time=0.442s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.720844 → 0.662716 (Δ=0.058128, rel=8.06%)
# Seed: 0 --- Kernel: mat52 --- itr: 109: best before=5.142699891897878, best after=5.142699891897878, curr query: [5.14269967], time=0.336s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.587227 → 0.533746 (Δ=0.053481, rel=9.11%)
# Seed: 0 --- Kernel: mat52 --- itr: 110: best before=5.142699891897878, best after=5.142699891897878, curr query: [2.53388374], time=0.267s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.541494 → 0.491570 (Δ=0.049924, rel=9.22%)
# Seed: 0 --- Kernel: mat52 --- itr: 111: best before=5.142699891897878, best after=5.142699891897878, curr query: [1.52695772], time=0.226s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.468007 → 0.423094 (Δ=0.044913, rel=9.60%)
# Seed: 0 --- Kernel: mat52 --- itr: 112: best before=5.142699891897878, best after=5.142699891897878, curr query: [2.59944463], time=0.431s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.434801 → 0.392679 (Δ=0.042123, rel=9.69%)
# Seed: 0 --- Kernel: mat52 --- itr: 113: best before=5.142699891897878, best after=5.142699891897878, curr query: [5.14269954], time=0.229s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.323739 → 0.284632 (Δ=0.039107, rel=12.08%)
# Seed: 0 --- Kernel: mat52 --- itr: 114: best before=5.142699891897878, best after=5.142699891897878, curr query: [4.43332035], time=0.422s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.286920 → 0.249916 (Δ=0.037004, rel=12.90%)
# Seed: 0 --- Kernel: mat52 --- itr: 115: best before=5.142699891897878, best after=5.142699891897878, curr query: [2.88236209], time=0.330s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.264397 → 0.229246 (Δ=0.035151, rel=13.29%)
# Seed: 0 --- Kernel: mat52 --- itr: 116: best before=5.142699891897878, best after=5.142699891897878, curr query: [3.46098775], time=0.440s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.244580 → 0.210991 (Δ=0.033589, rel=13.73%)
# Seed: 0 --- Kernel: mat52 --- itr: 117: best before=5.142699891897878, best after=5.142699891897878, curr query: [5.14269944], time=0.572s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.147102 → 0.115763 (Δ=0.031338, rel=21.30%)
# Seed: 0 --- Kernel: mat52 --- itr: 118: best before=5.142699891897878, best after=5.142699891897878, curr query: [5.14269983], time=0.550s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.053908 → 0.024683 (Δ=0.029225, rel=54.21%)
# Seed: 0 --- Kernel: mat52 --- itr: 119: best before=5.142699891897878, best after=5.142699891897878, curr query: [4.14138244], time=0.320s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.042710 → 0.014762 (Δ=0.027948, rel=65.44%)
# Seed: 0 --- Kernel: mat52 --- itr: 120: best before=5.142699891897878, best after=5.142699891897878, curr query: [3.32241474], time=0.440s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.111714 → 0.109966 (Δ=0.001748, rel=1.57%)
# Cloning
# [GP_Wrapper.step] 1000 epochs: 1.794773 → 1.266507 (Δ=0.528266, rel=29.43%)
# [GP_Wrapper.step] 2000 epochs: 1.794773 → 1.266507 (Δ=0.528266, rel=29.43%)
# Seed: 0 --- Kernel: mat12 --- itr: 21: best before=4.073756088146656, best after=4.310365442805317, curr query: [4.31036544], time=2.150s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.152990 → 1.137153 (Δ=0.015836, rel=1.37%)
# Seed: 0 --- Kernel: mat12 --- itr: 22: best before=4.310365442805317, best after=4.310365442805317, curr query: [3.9749699], time=0.113s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.050401 → 1.044759 (Δ=0.005641, rel=0.54%)
# Seed: 0 --- Kernel: mat12 --- itr: 23: best before=4.310365442805317, best after=4.310365442805317, curr query: [4.31036544], time=0.074s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.542955 → 0.613559 (Δ=-0.070604, rel=-13.00%)
# Seed: 0 --- Kernel: mat12 --- itr: 24: best before=4.310365442805317, best after=4.310365442805317, curr query: [4.31036544], time=0.070s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.137719 → 0.185430 (Δ=-0.047711, rel=-34.64%)
# Seed: 0 --- Kernel: mat12 --- itr: 25: best before=4.310365442805317, best after=4.310365442805317, curr query: [4.31036544], time=0.073s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.227659 → 0.253219 (Δ=-0.025560, rel=-11.23%)
# Seed: 0 --- Kernel: mat12 --- itr: 26: best before=4.310365442805317, best after=4.310365442805317, curr query: [3.8261816], time=0.074s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.248225 → 0.579487 (Δ=-0.331261, rel=-133.45%)
# Seed: 0 --- Kernel: mat12 --- itr: 27: best before=4.310365442805317, best after=4.310365442805317, curr query: [4.31036544], time=0.079s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.610318 → 0.064932 (Δ=0.545386, rel=89.36%)
# Seed: 0 --- Kernel: mat12 --- itr: 28: best before=4.310365442805317, best after=4.310365442805317, curr query: [3.42610462], time=0.086s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.447148 → 0.015181 (Δ=0.431968, rel=96.61%)
# Seed: 0 --- Kernel: mat12 --- itr: 29: best before=4.310365442805317, best after=4.310365442805317, curr query: [4.31036544], time=0.079s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.389732 → 0.337895 (Δ=0.051837, rel=13.30%)
# Seed: 0 --- Kernel: mat12 --- itr: 30: best before=4.310365442805317, best after=4.310365442805317, curr query: [4.31036544], time=0.072s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.075570 → 0.041913 (Δ=0.033657, rel=44.54%)
# Seed: 0 --- Kernel: mat12 --- itr: 31: best before=4.310365442805317, best after=4.310365442805317, curr query: [4.31036544], time=0.071s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -0.181638 → -0.228726 (Δ=0.047088, rel=25.92%)
# Seed: 0 --- Kernel: mat12 --- itr: 32: best before=4.310365442805317, best after=4.310365442805317, curr query: [4.31036544], time=0.072s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -0.478389 → -0.441148 (Δ=-0.037241, rel=-7.78%)
# Seed: 0 --- Kernel: mat12 --- itr: 33: best before=4.310365442805317, best after=4.310365442805317, curr query: [3.98129332], time=0.079s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -0.422919 → -1.542215 (Δ=1.119296, rel=264.66%)
# Seed: 0 --- Kernel: mat12 --- itr: 34: best before=4.310365442805317, best after=4.310365442805317, curr query: [4.2123927], time=0.121s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -0.126294 → -0.852069 (Δ=0.725775, rel=574.67%)
# Seed: 0 --- Kernel: mat12 --- itr: 35: best before=4.310365442805317, best after=4.310365442805317, curr query: [3.84554637], time=0.180s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -1.152856 → -1.084019 (Δ=-0.068837, rel=-5.97%)
# Seed: 0 --- Kernel: mat12 --- itr: 36: best before=4.310365442805317, best after=4.310365442805317, curr query: [4.00743932], time=0.174s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -1.340063 → -1.341449 (Δ=0.001386, rel=0.10%)
# Seed: 0 --- Kernel: mat12 --- itr: 37: best before=4.310365442805317, best after=4.310365442805317, curr query: [3.92024655], time=0.188s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -1.286170 → -1.286395 (Δ=0.000224, rel=0.02%)
# Seed: 0 --- Kernel: mat12 --- itr: 38: best before=4.310365442805317, best after=4.310365442805317, curr query: [3.84029744], time=0.158s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -1.234219 → -1.234408 (Δ=0.000189, rel=0.02%)
# Seed: 0 --- Kernel: mat12 --- itr: 39: best before=4.310365442805317, best after=4.310365442805317, curr query: [3.89449384], time=0.111s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -1.190992 → -1.191139 (Δ=0.000148, rel=0.01%)
# Seed: 0 --- Kernel: mat12 --- itr: 40: best before=4.310365442805317, best after=4.646062496692794, curr query: [4.6460625], time=0.162s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -1.137667 → -1.137761 (Δ=0.000094, rel=0.01%)
# Seed: 0 --- Kernel: mat12 --- itr: 41: best before=4.646062496692794, best after=4.646062496692794, curr query: [3.61996429], time=0.131s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -0.838954 → -0.839162 (Δ=0.000208, rel=0.02%)
# Seed: 0 --- Kernel: mat12 --- itr: 42: best before=4.646062496692794, best after=4.646062496692794, curr query: [3.93650359], time=0.171s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -1.050573 → -1.050775 (Δ=0.000201, rel=0.02%)
# Seed: 0 --- Kernel: mat12 --- itr: 43: best before=4.646062496692794, best after=4.944005877201577, curr query: [4.94400588], time=0.204s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -1.016836 → -1.017100 (Δ=0.000264, rel=0.03%)
# Seed: 0 --- Kernel: mat12 --- itr: 44: best before=4.944005877201577, best after=5.041434124684014, curr query: [5.04143412], time=0.322s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -1.013758 → -1.013974 (Δ=0.000216, rel=0.02%)
# Seed: 0 --- Kernel: mat12 --- itr: 45: best before=5.041434124684014, best after=5.091448227339866, curr query: [5.09144823], time=0.304s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -1.003202 → -1.003388 (Δ=0.000186, rel=0.02%)
# Seed: 0 --- Kernel: mat12 --- itr: 46: best before=5.091448227339866, best after=5.112730882763597, curr query: [5.11273088], time=0.189s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: -1.006708 → -1.006874 (Δ=0.000166, rel=0.02%)
# Seed: 0 --- Kernel: mat12 --- itr: 47: best before=5.112730882763597, best after=5.112730882763597, curr query: [5.06295052], time=0.295s
# ...
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.026712 → -4.847745 (Δ=1.821033, rel=60.17%)
# Seed: 0 --- Kernel: gcauchy --- itr: 80: best before=5.142652129603213, best after=5.142652129603213, curr query: [5.12289532], time=0.359s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.005884 → -3.007150 (Δ=0.001266, rel=0.04%)
# Seed: 0 --- Kernel: gcauchy --- itr: 81: best before=5.142652129603213, best after=5.142652129603213, curr query: [3.60935385], time=0.199s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -2.960506 → -2.960238 (Δ=-0.000268, rel=-0.01%)
# Seed: 0 --- Kernel: gcauchy --- itr: 82: best before=5.142652129603213, best after=5.142652129603213, curr query: [5.10010252], time=0.474s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -2.939528 → -2.931358 (Δ=-0.008170, rel=-0.28%)
# Seed: 0 --- Kernel: gcauchy --- itr: 83: best before=5.142652129603213, best after=5.142652129603213, curr query: [3.40051846], time=0.245s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -2.884228 → -2.893089 (Δ=0.008861, rel=0.31%)
# Seed: 0 --- Kernel: gcauchy --- itr: 84: best before=5.142652129603213, best after=5.142652129603213, curr query: [5.09525738], time=0.829s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -2.878813 → -2.880776 (Δ=0.001964, rel=0.07%)
# Seed: 0 --- Kernel: gcauchy --- itr: 85: best before=5.142652129603213, best after=5.142652129603213, curr query: [4.94855405], time=0.326s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -2.809269 → -2.813000 (Δ=0.003731, rel=0.13%)
# Seed: 0 --- Kernel: gcauchy --- itr: 86: best before=5.142652129603213, best after=5.142652129603213, curr query: [5.09124068], time=0.769s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.671886 → -2.332870 (Δ=3.004756, rel=447.21%)
# [GP_Wrapper.step] 2000 epochs: 20.854454 → -3.048891 (Δ=23.903345, rel=114.62%)
# Seed: 0 --- Kernel: gcauchy --- itr: 87: best before=5.142652129603213, best after=5.142652129603213, curr query: [4.91610452], time=5.485s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.019784 → -3.041187 (Δ=0.021402, rel=0.71%)
# Seed: 0 --- Kernel: gcauchy --- itr: 88: best before=5.142652129603213, best after=5.142652129603213, curr query: [4.26694731], time=0.934s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.001239 → -3.021451 (Δ=0.020212, rel=0.67%)
# Seed: 0 --- Kernel: gcauchy --- itr: 89: best before=5.142652129603213, best after=5.142652129603213, curr query: [5.13719169], time=0.445s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.005351 → -3.025676 (Δ=0.020325, rel=0.68%)
# Seed: 0 --- Kernel: gcauchy --- itr: 90: best before=5.142652129603213, best after=5.142652129603213, curr query: [5.14154023], time=0.412s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.035112 → -3.056767 (Δ=0.021655, rel=0.71%)
# Seed: 0 --- Kernel: gcauchy --- itr: 91: best before=5.142652129603213, best after=5.142652129603213, curr query: [4.51732241], time=0.533s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.018326 → -3.039083 (Δ=0.020757, rel=0.69%)
# Seed: 0 --- Kernel: gcauchy --- itr: 92: best before=5.142652129603213, best after=5.142652129603213, curr query: [5.14262787], time=1.020s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.066285 → -3.088677 (Δ=0.022392, rel=0.73%)
# Seed: 0 --- Kernel: gcauchy --- itr: 93: best before=5.142652129603213, best after=5.142652129603213, curr query: [5.14227393], time=0.949s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.127162 → -3.144209 (Δ=0.017048, rel=0.55%)
# Seed: 0 --- Kernel: gcauchy --- itr: 94: best before=5.142652129603213, best after=5.142652129603213, curr query: [2.96968476], time=0.854s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.096734 → -3.124754 (Δ=0.028020, rel=0.90%)
# Seed: 0 --- Kernel: gcauchy --- itr: 95: best before=5.142652129603213, best after=5.142652129603213, curr query: [4.89399937], time=0.482s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.090871 → -6.261408 (Δ=3.170537, rel=102.58%)
# Seed: 0 --- Kernel: gcauchy --- itr: 96: best before=5.142652129603213, best after=5.142652129603213, curr query: [5.14257212], time=0.286s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -6.267791 → -3.173129 (Δ=-3.094662, rel=-49.37%)
# Seed: 0 --- Kernel: gcauchy --- itr: 97: best before=5.142652129603213, best after=5.142698620725889, curr query: [5.14269862], time=0.345s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.221172 → -3.242814 (Δ=0.021642, rel=0.67%)
# Seed: 0 --- Kernel: gcauchy --- itr: 98: best before=5.142698620725889, best after=5.142698620725889, curr query: [5.14268183], time=0.797s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.286736 → -6.376840 (Δ=3.090104, rel=94.02%)
# Seed: 0 --- Kernel: gcauchy --- itr: 99: best before=5.142698620725889, best after=5.142698620725889, curr query: [3.42424432], time=1.225s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -6.299053 → -3.285634 (Δ=-3.013418, rel=-47.84%)
# Seed: 0 --- Kernel: gcauchy --- itr: 100: best before=5.142698620725889, best after=5.14269989032491, curr query: [5.14269989], time=0.349s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.333472 → -6.383418 (Δ=3.049946, rel=91.49%)
# Seed: 0 --- Kernel: gcauchy --- itr: 101: best before=5.14269989032491, best after=5.14269989032491, curr query: [5.14269642], time=0.244s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -6.418254 → -6.447388 (Δ=0.029134, rel=0.45%)
# Seed: 0 --- Kernel: gcauchy --- itr: 102: best before=5.14269989032491, best after=5.14269989206408, curr query: [5.14269989], time=0.694s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.459416 → -3.473421 (Δ=0.014006, rel=0.40%)
# Seed: 0 --- Kernel: gcauchy --- itr: 103: best before=5.14269989206408, best after=5.14269989206408, curr query: [5.1426997], time=0.752s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.518936 → -3.530441 (Δ=0.011505, rel=0.33%)
# Seed: 0 --- Kernel: gcauchy --- itr: 104: best before=5.14269989206408, best after=5.14269989206408, curr query: [3.07099967], time=0.531s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.486375 → -3.495306 (Δ=0.008931, rel=0.26%)
# Seed: 0 --- Kernel: gcauchy --- itr: 105: best before=5.14269989206408, best after=5.14269989206408, curr query: [5.14269986], time=0.814s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.540120 → -3.548441 (Δ=0.008321, rel=0.24%)
# Seed: 0 --- Kernel: gcauchy --- itr: 106: best before=5.14269989206408, best after=5.14269989206408, curr query: [5.14269989], time=0.665s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.592351 → -3.598718 (Δ=0.006367, rel=0.18%)
# Seed: 0 --- Kernel: gcauchy --- itr: 107: best before=5.14269989206408, best after=5.14269989206408, curr query: [5.14269988], time=0.921s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.641820 → -3.648189 (Δ=0.006368, rel=0.17%)
# Seed: 0 --- Kernel: gcauchy --- itr: 108: best before=5.14269989206408, best after=5.14269989206408, curr query: [5.14269989], time=0.722s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.690418 → -3.694375 (Δ=0.003956, rel=0.11%)
# Seed: 0 --- Kernel: gcauchy --- itr: 109: best before=5.14269989206408, best after=5.14269989206408, curr query: [5.14269989], time=0.367s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.735848 → -3.738960 (Δ=0.003113, rel=0.08%)
# Seed: 0 --- Kernel: gcauchy --- itr: 110: best before=5.14269989206408, best after=5.14269989206408, curr query: [5.14269988], time=0.767s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.779613 → -3.782348 (Δ=0.002735, rel=0.07%)
# Seed: 0 --- Kernel: gcauchy --- itr: 111: best before=5.14269989206408, best after=5.14269989206408, curr query: [4.90386928], time=1.197s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.774320 → -3.776963 (Δ=0.002643, rel=0.07%)
# Seed: 0 --- Kernel: gcauchy --- itr: 112: best before=5.14269989206408, best after=5.14269989206408, curr query: [5.14269988], time=0.918s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.816566 → -3.818314 (Δ=0.001748, rel=0.05%)
# Seed: 0 --- Kernel: gcauchy --- itr: 113: best before=5.14269989206408, best after=5.14269989206408, curr query: [5.14269989], time=0.433s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.857167 → -3.858989 (Δ=0.001823, rel=0.05%)
# Seed: 0 --- Kernel: gcauchy --- itr: 114: best before=5.14269989206408, best after=5.14269989206408, curr query: [4.90570944], time=0.708s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.886753 → -3.888367 (Δ=0.001613, rel=0.04%)
# Seed: 0 --- Kernel: gcauchy --- itr: 115: best before=5.14269989206408, best after=5.14269989206408, curr query: [5.14269989], time=0.768s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.925935 → -3.927179 (Δ=0.001245, rel=0.03%)
# Seed: 0 --- Kernel: gcauchy --- itr: 116: best before=5.14269989206408, best after=5.14269989206408, curr query: [4.90571061], time=0.780s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.960989 → -3.962258 (Δ=0.001269, rel=0.03%)
# Seed: 0 --- Kernel: gcauchy --- itr: 117: best before=5.14269989206408, best after=5.14269989206408, curr query: [5.14269989], time=0.397s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.998514 → -3.999382 (Δ=0.000868, rel=0.02%)
# Seed: 0 --- Kernel: gcauchy --- itr: 118: best before=5.14269989206408, best after=5.14269989206408, curr query: [4.01093387], time=0.532s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.959376 → -3.960250 (Δ=0.000874, rel=0.02%)
# Seed: 0 --- Kernel: gcauchy --- itr: 119: best before=5.14269989206408, best after=5.14269989206408, curr query: [5.14269989], time=1.135s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -3.995944 → -3.996837 (Δ=0.000893, rel=0.02%)
# Seed: 0 --- Kernel: gcauchy --- itr: 120: best before=5.14269989206408, best after=5.14269989206408, curr query: [5.14269989], time=0.436s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/gcauchy/hyperparams_Ackley_gcauchy_seed0.csv
# [GP_Wrapper.step] 50 epochs: -4.291017 → -2.608715 (Δ=-1.682301, rel=-39.21%)
