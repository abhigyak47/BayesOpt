# %%
# import sys
# sys.path.append('/Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/')

import numpy as np
import matplotlib.pyplot as plt
import torch
import warnings
from gpytorch.kernels import MaternKernel, ScaleKernel, RQKernel
import matplotlib as mpl
from BO_loop import BO_loop_GP, GP_Wrapper
from data import BayesOptDataset, FuncAckley
from sklearn.preprocessing import MinMaxScaler
import copy
from matplotlib.lines import Line2D
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.gridspec as gridspec

warnings.filterwarnings('ignore')

# %%
# Set random seeds
SEED = 0
np.random.seed(SEED)
torch.manual_seed(SEED)

KERNEL_FLAGS = {
    "mat52": {"kernel": "mat52", "set_ls": False, "if_ard": False},
    "mat12": {"kernel": "mat12", "set_ls": False, "if_ard": False},
    "rq":    {"kernel": "rq",    "set_ls": False, "if_ard": False},
    "gcauchy": {"kernel": "gcauchy", "set_ls": False, "if_ard": False}
}

# Define consistent colors
colors_dict = {
    "gp_mean": "#1f77b4",       # blue
    "true_func": "#000000",     # black
    "samples": "#2ca02c",       # green
    "global_min": "#d62728",    # red
    "fill": "#1f77b4",          # same as gp_mean, but transparent
}

# %%
def BO_UCB_plot_grid(kernel_types, kernel_names, dataset, total_iter=15, beta=1.5):
    # Configure plotting style
    mpl.rcParams.update({
        'font.family': 'sans-serif',
        'font.sans-serif': ['Arial', 'DejaVu Sans', 'Liberation Sans'],
        'font.size': 11,
        'axes.labelsize': 11,
        'axes.titlesize': 11,
        'xtick.labelsize': 10,
        'ytick.labelsize': 10,
        'legend.fontsize': 10,
        'figure.titlesize': 11,
        'figure.dpi': 200
    })

    num_rows = len(kernel_types)
    milestones = [0, total_iter // 3, 2 * total_iter // 3, total_iter]
    num_cols = len(milestones)

    fig = plt.figure(figsize=(8, 2.5 * num_rows + 1), constrained_layout=True, dpi=200)
    gs = gridspec.GridSpec(num_rows + 1, num_cols,
                           height_ratios=[1] + [1] * num_rows,
                           figure=fig)
                           
    # Get true function values for plotting
    lb = dataset.func.lb
    ub = dataset.func.ub
    X_plot = np.linspace(lb[0], ub[0], 100)
    Y_plot = np.linspace(lb[1], ub[1], 100)
    X_grid, Y_grid = np.meshgrid(X_plot, Y_plot)
    XY_grid = np.column_stack((X_grid.ravel(), Y_grid.ravel()))
    Z_true = dataset.func.query(XY_grid).reshape(X_grid.shape)
    
    # True contour plot (using original scale)
    ax_true = fig.add_subplot(gs[0, 0])
    cntr = ax_true.contourf(X_grid, Y_grid, Z_true, levels=30, cmap='viridis')
    
    x_init_denorm = dataset.func.inputs_scaler.inverse_transform(dataset.X)
    ax_true.scatter(x_init_denorm[:, 0], x_init_denorm[:, 1], c='red', edgecolors='k', s=40, linewidth=0.5)
    
    x_true_min_denorm, _ = dataset.func.get_opts()
    ax_true.scatter(x_true_min_denorm[:, 0], x_true_min_denorm[:, 1], c='green', marker='*', s=150)
    
    ax_true.set_title("True Contour Plot")
    ax_true.set_xlabel("x1")
    ax_true.set_ylabel("x2")

    divider = make_axes_locatable(ax_true)
    cax = divider.append_axes("right", size="5%", pad=0.05)
    cbar = fig.colorbar(cntr, cax=cax)
    cbar.set_label("Objective Value")
    
    # Legend in the top row
    legend_ax = fig.add_subplot(gs[0, 1:])
    legend_ax.axis('off')
    handles = [
        plt.Line2D([], [], marker='o', linestyle='', color='red', markeredgecolor='k', markersize=8, label='Samples'),
        plt.Line2D([], [], marker='*', linestyle='', color='green', markersize=12, label='True Minimum')
    ]
    legend_ax.legend(handles=handles, loc='center', frameon=False, ncol=2)

    for i, kernel_type in enumerate(kernel_types):
        current_dataset = dataset.clone()
        flags = KERNEL_FLAGS[kernel_type]
        base_kern = flags["kernel"]
        set_ls = flags["set_ls"]
        if_ard = flags["if_ard"]

        X_init, Y_init = current_dataset.get_data(normalize=True)
        gp_model = GP_Wrapper(
            X_init, Y_init,
            kernel=base_kern,
            if_ard=if_ard,
            if_softplus=True,
            set_ls=set_ls,
            device="cpu",
        )
        gp_model.init_optimizer(lr=0.01, optim="ADAM")
        gp_model.step(epochs=400)

        for j, n in enumerate(milestones):
            if n > 0:
                BO_loop_GP(
                    func_name="Ackley",
                    dataset=current_dataset,
                    seed=SEED,
                    num_step=n - milestones[j-1],
                    beta=beta,
                    if_ard=if_ard,
                    if_softplus=True,
                    acqf_type="UCB",
                    set_ls=set_ls,
                    kernel_type=base_kern,
                    full_kernel_name=kernel_type,
                    device="cpu"
                )
                X, Y = current_dataset.get_data(normalize=True)
                gp_model.update_train_data(X, Y)
                gp_model.step(epochs=50)

            ax = fig.add_subplot(gs[i + 1, j])

            mu, _ = plot_gp_state_2d(gp_model, dataset, X_grid, Y_grid, ax)
            cntr_gp = ax.contourf(X_grid, Y_grid, mu, levels=30, cmap='viridis')
            
            X_denorm = dataset.func.inputs_scaler.inverse_transform(current_dataset.X)
            ax.scatter(X_denorm[:, 0], X_denorm[:, 1], c='red', edgecolors='k', s=40, linewidth=0.5)

            x_true_min_denorm, _ = dataset.func.get_opts()
            ax.scatter(x_true_min_denorm[:, 0], x_true_min_denorm[:, 1], c='green', marker='*', s=150)

            ax.set_title(f"{kernel_names[i]}, Iter {n}")
            
            if i == num_rows - 1:
                ax.set_xlabel("x1")
            else:
                ax.set_xticklabels([])
            
            if j == 0:
                ax.set_ylabel("x2")
            else:
                ax.set_yticklabels([])

    plt.show()
    plt.close()

def plot_gp_state_2d(gp, dataset, X_grid, Y_grid, ax):
    gp.gp_model.eval()
    gp.likelihood.eval()
    
    XY_grid = np.column_stack((X_grid.ravel(), Y_grid.ravel()))
    XY_grid_norm = dataset.func.inputs_scaler.transform(XY_grid)
    
    with torch.no_grad():
        posterior = gp.likelihood(gp.gp_model(torch.tensor(XY_grid_norm)))
    
    mu_norm = posterior.mean.numpy()
    mu = mu_norm * dataset.scaler.scale_[0] + dataset.scaler.mean_[0]
    mu = mu.reshape(X_grid.shape)
    
    return mu, None

if __name__ == "__main__":
    
    func_2d = FuncAckley(dim=2)
    dataset_2d = BayesOptDataset(func_2d, n_init=5, method='lhs', seed=SEED)
    
    kernel_types = ["mat52", "mat12", "rq"]
    kernel_names = ["Matern 5/2", "Matern 1/2", "Rational Quadratic"]

    print("Generating 2D plots for Ackley function...")
    BO_UCB_plot_grid(
        kernel_types=kernel_types,
        kernel_names=kernel_names,
        dataset=dataset_2d,
        total_iter=15,
        beta=1.5
    )
# Out:
# Generating 2D plots for Ackley function...
# Cloning
# [GP_Wrapper.step] 400 epochs: 7.889349 → 1.669929 (Δ=6.219419, rel=78.83%)
# [GP_Wrapper.step] 2000 epochs: 7.889349 → 1.418960 (Δ=6.470389, rel=82.01%)
# Seed: 0 --- Kernel: mat52 --- itr: 6: best before=-19.519083969343978, best after=-19.519083969343978, curr query: [-20.41716344], time=2.674s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.423473 → 1.372782 (Δ=0.050691, rel=3.56%)
# Seed: 0 --- Kernel: mat52 --- itr: 7: best before=-19.519083969343978, best after=-19.519083969343978, curr query: [-19.98483831], time=0.216s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.263822 → 1.245985 (Δ=0.017837, rel=1.41%)
# Seed: 0 --- Kernel: mat52 --- itr: 8: best before=-19.519083969343978, best after=-19.519083969343978, curr query: [-20.54084601], time=0.148s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.433630 → 1.304489 (Δ=0.129141, rel=9.01%)
# Seed: 0 --- Kernel: mat52 --- itr: 9: best before=-19.519083969343978, best after=-19.519083969343978, curr query: [-20.8820089], time=0.077s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.820464 → 1.419542 (Δ=0.400922, rel=22.02%)
# Seed: 0 --- Kernel: mat52 --- itr: 10: best before=-19.519083969343978, best after=-19.519083969343978, curr query: [-20.09376027], time=0.111s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 17052.721028 → 526.284164 (Δ=16526.436865, rel=96.91%)
# [GP_Wrapper.step] 2000 epochs: 565891.048892 → 11.922205 (Δ=565879.126687, rel=100.00%)
# Seed: 0 --- Kernel: mat52 --- itr: 11: best before=-19.519083969343978, best after=-19.519083969343978, curr query: [-21.07011193], time=2.765s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 12.683542 → 12.067574 (Δ=0.615968, rel=4.86%)
# Seed: 0 --- Kernel: mat52 --- itr: 12: best before=-19.519083969343978, best after=-19.519083969343978, curr query: [-20.60978359], time=0.416s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 15.409725 → 14.435784 (Δ=0.973941, rel=6.32%)
# Seed: 0 --- Kernel: mat52 --- itr: 13: best before=-19.519083969343978, best after=-18.597711581897137, curr query: [-18.59771158], time=0.258s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 62.195298 → 46.994594 (Δ=15.200704, rel=24.44%)
# Seed: 0 --- Kernel: mat52 --- itr: 14: best before=-18.597711581897137, best after=-18.597711581897137, curr query: [-20.53538088], time=0.381s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 47.144333 → 36.575408 (Δ=10.568925, rel=22.42%)
# Seed: 0 --- Kernel: mat52 --- itr: 15: best before=-18.597711581897137, best after=-18.597711581897137, curr query: [-20.26536382], time=0.243s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 5681.684525 → 467.250791 (Δ=5214.433734, rel=91.78%)
# [GP_Wrapper.step] 2000 epochs: 1323954.196906 → 15.778822 (Δ=1323938.418084, rel=100.00%)
# Seed: 0 --- Kernel: mat52 --- itr: 16: best before=-18.597711581897137, best after=-18.597711581897137, curr query: [-18.85312519], time=2.449s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 20.101942 → 18.958816 (Δ=1.143126, rel=5.69%)
# Seed: 0 --- Kernel: mat52 --- itr: 17: best before=-18.597711581897137, best after=-18.597711581897137, curr query: [-19.8816329], time=0.137s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 41.971494 → 36.538353 (Δ=5.433141, rel=12.94%)
# Seed: 0 --- Kernel: mat52 --- itr: 18: best before=-18.597711581897137, best after=-18.597711581897137, curr query: [-19.80585879], time=0.132s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 35.734740 → 31.235509 (Δ=4.499231, rel=12.59%)
# Seed: 0 --- Kernel: mat52 --- itr: 19: best before=-18.597711581897137, best after=-18.597711581897137, curr query: [-21.12062809], time=0.188s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 30.020826 → 26.737667 (Δ=3.283159, rel=10.94%)
# Seed: 0 --- Kernel: mat52 --- itr: 20: best before=-18.597711581897137, best after=-18.597711581897137, curr query: [-20.33419319], time=0.233s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat52/hyperparams_Ackley_mat52_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1691.201239 → 400.450491 (Δ=1290.750748, rel=76.32%)
# Cloning
# [GP_Wrapper.step] 400 epochs: 2.715388 → 1.486677 (Δ=1.228710, rel=45.25%)
# [GP_Wrapper.step] 2000 epochs: 2.715388 → 1.418941 (Δ=1.296447, rel=47.74%)
# Seed: 0 --- Kernel: mat12 --- itr: 6: best before=-19.519083969343978, best after=-19.519083969343978, curr query: [-20.50532962], time=2.208s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.463491 → 1.387108 (Δ=0.076383, rel=5.22%)
# Seed: 0 --- Kernel: mat12 --- itr: 7: best before=-19.519083969343978, best after=-19.519083969343978, curr query: [-19.5655663], time=0.100s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.213682 → 1.160831 (Δ=0.052851, rel=4.35%)
# Seed: 0 --- Kernel: mat12 --- itr: 8: best before=-19.519083969343978, best after=-19.495915045277304, curr query: [-19.49591505], time=0.116s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.055358 → 1.036300 (Δ=0.019058, rel=1.81%)
# Seed: 0 --- Kernel: mat12 --- itr: 9: best before=-19.495915045277304, best after=-19.495915045277304, curr query: [-20.54811422], time=0.186s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.174637 → 1.113945 (Δ=0.060692, rel=5.17%)
# Seed: 0 --- Kernel: mat12 --- itr: 10: best before=-19.495915045277304, best after=-18.74213941407923, curr query: [-18.74213941], time=0.105s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 2.848704 → 1.385437 (Δ=1.463267, rel=51.37%)
# [GP_Wrapper.step] 2000 epochs: 22.554813 → 1.104363 (Δ=21.450450, rel=95.10%)
# Seed: 0 --- Kernel: mat12 --- itr: 11: best before=-18.74213941407923, best after=-18.542406153629635, curr query: [-18.54240615], time=2.837s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.975722 → 0.967585 (Δ=0.008137, rel=0.83%)
# Seed: 0 --- Kernel: mat12 --- itr: 12: best before=-18.542406153629635, best after=-18.47157844807714, curr query: [-18.47157845], time=0.141s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.847710 → 0.840185 (Δ=0.007525, rel=0.89%)
# Seed: 0 --- Kernel: mat12 --- itr: 13: best before=-18.47157844807714, best after=-18.47157844807714, curr query: [-18.5534144], time=0.242s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.739293 → 0.733284 (Δ=0.006008, rel=0.81%)
# Seed: 0 --- Kernel: mat12 --- itr: 14: best before=-18.47157844807714, best after=-18.47157844807714, curr query: [-18.56909281], time=0.135s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.623786 → 0.619109 (Δ=0.004677, rel=0.75%)
# Seed: 0 --- Kernel: mat12 --- itr: 15: best before=-18.47157844807714, best after=-18.43978091988076, curr query: [-18.43978092], time=0.229s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.624579 → 0.609572 (Δ=0.015007, rel=2.40%)
# [GP_Wrapper.step] 2000 epochs: 12.166728 → 0.530032 (Δ=11.636696, rel=95.64%)
# Seed: 0 --- Kernel: mat12 --- itr: 16: best before=-18.43978091988076, best after=-18.43978091988076, curr query: [-18.49345442], time=2.364s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.450668 → 0.448145 (Δ=0.002523, rel=0.56%)
# Seed: 0 --- Kernel: mat12 --- itr: 17: best before=-18.43978091988076, best after=-18.43978091988076, curr query: [-18.45845827], time=0.174s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.349129 → 0.346960 (Δ=0.002169, rel=0.62%)
# Seed: 0 --- Kernel: mat12 --- itr: 18: best before=-18.43978091988076, best after=-18.43978091988076, curr query: [-18.44421797], time=0.221s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.268995 → 0.267217 (Δ=0.001778, rel=0.66%)
# Seed: 0 --- Kernel: mat12 --- itr: 19: best before=-18.43978091988076, best after=-18.43978091988076, curr query: [-18.70323315], time=1.756s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.235284 → 0.234299 (Δ=0.000985, rel=0.42%)
# Seed: 0 --- Kernel: mat12 --- itr: 20: best before=-18.43978091988076, best after=-18.43978091988076, curr query: [-18.44307339], time=0.295s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/mat12/hyperparams_Ackley_mat12_seed0.csv
# [GP_Wrapper.step] 50 epochs: 0.227942 → 0.208260 (Δ=0.019682, rel=8.63%)
# Cloning
# [GP_Wrapper.step] 400 epochs: 12.849809 → 1.799764 (Δ=11.050045, rel=85.99%)
# [GP_Wrapper.step] 2000 epochs: 12.849809 → 1.419001 (Δ=11.430808, rel=88.96%)
# Seed: 0 --- Kernel: rq --- itr: 6: best before=-19.519083969343978, best after=-19.519083969343978, curr query: [-20.68804125], time=3.543s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/rq/hyperparams_Ackley_rq_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.558326 → 1.408175 (Δ=0.150151, rel=9.64%)
# Seed: 0 --- Kernel: rq --- itr: 7: best before=-19.519083969343978, best after=-19.519083969343978, curr query: [-20.20918069], time=0.197s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/rq/hyperparams_Ackley_rq_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.359747 → 1.333132 (Δ=0.026616, rel=1.96%)
# Seed: 0 --- Kernel: rq --- itr: 8: best before=-19.519083969343978, best after=-19.519083969343978, curr query: [-20.1866048], time=0.121s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/rq/hyperparams_Ackley_rq_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.330279 → 1.280928 (Δ=0.049351, rel=3.71%)
# Seed: 0 --- Kernel: rq --- itr: 9: best before=-19.519083969343978, best after=-19.519083969343978, curr query: [-19.52825682], time=0.107s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/rq/hyperparams_Ackley_rq_seed0.csv
# [GP_Wrapper.step] 50 epochs: 1.132726 → 1.104148 (Δ=0.028578, rel=2.52%)
# Seed: 0 --- Kernel: rq --- itr: 10: best before=-19.519083969343978, best after=-18.48094532488794, curr query: [-18.48094532], time=0.155s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/rq/hyperparams_Ackley_rq_seed0.csv
# [GP_Wrapper.step] 50 epochs: 167177.935685 → 1973.416295 (Δ=165204.519390, rel=98.82%)
# [GP_Wrapper.step] 2000 epochs: 972683.552650 → 11.533338 (Δ=972672.019312, rel=100.00%)
# Seed: 0 --- Kernel: rq --- itr: 11: best before=-18.48094532488794, best after=-18.48094532488794, curr query: [-19.31912436], time=3.273s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/rq/hyperparams_Ackley_rq_seed0.csv
# [GP_Wrapper.step] 50 epochs: 19.495198 → 17.786710 (Δ=1.708488, rel=8.76%)
# Seed: 0 --- Kernel: rq --- itr: 12: best before=-18.48094532488794, best after=-18.48094532488794, curr query: [-20.78913752], time=0.548s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/rq/hyperparams_Ackley_rq_seed0.csv
# [GP_Wrapper.step] 50 epochs: 17.803701 → 16.181990 (Δ=1.621711, rel=9.11%)
# Seed: 0 --- Kernel: rq --- itr: 13: best before=-18.48094532488794, best after=-18.48094532488794, curr query: [-20.10429031], time=0.268s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/rq/hyperparams_Ackley_rq_seed0.csv
# [GP_Wrapper.step] 50 epochs: 16.175422 → 14.849742 (Δ=1.325680, rel=8.20%)
# Seed: 0 --- Kernel: rq --- itr: 14: best before=-18.48094532488794, best after=-18.48094532488794, curr query: [-19.77153878], time=0.394s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/rq/hyperparams_Ackley_rq_seed0.csv
# [GP_Wrapper.step] 50 epochs: 14.585494 → 13.521116 (Δ=1.064378, rel=7.30%)
# Seed: 0 --- Kernel: rq --- itr: 15: best before=-18.48094532488794, best after=-18.48094532488794, curr query: [-19.42962398], time=0.308s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/rq/hyperparams_Ackley_rq_seed0.csv
# [GP_Wrapper.step] 50 epochs: 19231.228906 → 736.501927 (Δ=18494.726978, rel=96.17%)
# [GP_Wrapper.step] 2000 epochs: 835524.617599 → 8.466932 (Δ=835516.150666, rel=100.00%)
# Seed: 0 --- Kernel: rq --- itr: 16: best before=-18.48094532488794, best after=-18.48094532488794, curr query: [-19.18048357], time=3.001s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/rq/hyperparams_Ackley_rq_seed0.csv
# [GP_Wrapper.step] 50 epochs: 7.897913 → 7.686347 (Δ=0.211566, rel=2.68%)
# Seed: 0 --- Kernel: rq --- itr: 17: best before=-18.48094532488794, best after=-18.44501245714683, curr query: [-18.44501246], time=0.347s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/rq/hyperparams_Ackley_rq_seed0.csv
# [GP_Wrapper.step] 50 epochs: 6.227907 → 6.086266 (Δ=0.141641, rel=2.27%)
# Seed: 0 --- Kernel: rq --- itr: 18: best before=-18.44501245714683, best after=-17.351621830899738, curr query: [-17.35162183], time=0.289s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/rq/hyperparams_Ackley_rq_seed0.csv
# [GP_Wrapper.step] 50 epochs: 5.615226 → 5.527932 (Δ=0.087295, rel=1.55%)
# Seed: 0 --- Kernel: rq --- itr: 19: best before=-17.351621830899738, best after=-17.351621830899738, curr query: [-18.25283784], time=0.369s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/rq/hyperparams_Ackley_rq_seed0.csv
# [GP_Wrapper.step] 50 epochs: 5.713396 → 5.612767 (Δ=0.100629, rel=1.76%)
# Seed: 0 --- Kernel: rq --- itr: 20: best before=-17.351621830899738, best after=-17.118049638315856, curr query: [-17.11804964], time=0.451s
# Saved hyperparameters to /Users/abhigyakoirala/Standard-GP-is-all-you-need-for-HDBO/FinalMain/BayesOpt/hyperparams/Ackley/rq/hyperparams_Ackley_rq_seed0.csv
# [GP_Wrapper.step] 50 epochs: 397.142641 → 237.410038 (Δ=159.732603, rel=40.22%)
